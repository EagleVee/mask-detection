# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import pandas as pd
from sklearn.model_selection import train_test_split
import shutil
import time
import copy

# %%
# !git clone https://github.com/EagleVee/mask-detection

# %%
# !ls ../experiements/dest_folder/
# Out:
# test      test.csv  train     train.csv val

# %% [markdown]
# ### Creating image datasets an data loaders for train and test using the experiments folder split

# %%
experiments_path = '../experiements/dest_folder/'
data_path = '../experiements/data/'

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.ToTensor(), 
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]), 
    'test' : transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
}

# %%
def get_train_files_path(experiments_path, data_path, phase):
    if phase == 'train':
        file_name = 'train.csv'
    elif phase == 'test':
        file_name = 'test.csv'
    else:
        print("phase can only have train and test as parameter values")
        exit()
    file_path = os.path.join(experiments_path, file_name)
    train_df = pd.read_csv(file_path, delimiter=',')
    files_path = []
    fonts_class = []
    for row in train_df.iterrows():
        files_path.append(os.path.join(data_path, row[1]['class'], row[1]['filename']))
        fonts_class.append(row[1]['class'])
    
    return files_path, fonts_class

# %%
def copy_images_to_path(file_path, file_class, destination_dir):
    font_folder = os.path.join(destination_dir, file_class)
    if os.path.exists(font_folder) == False:
        os.makedirs(font_folder)
    
    print("File being copied from {}:{}".format(file_path, font_folder))
    shutil.copy(file_path, font_folder)
    #shutil.copyfile(file_path, font_folder)

# %%
X_train, y_train = get_train_files_path(experiments_path, data_path, phase='train')
X_test, y_test = get_train_files_path(experiments_path, data_path, phase='test')

# %%
train_dir = os.path.join(experiments_path, 'train')
test_dir = os.path.join(experiments_path, 'test')

if not os.path.exists(train_dir):
    os.makedirs(train_dir)

if not os.path.exists(test_dir):
    os.makedirs(test_dir)

# %%
for file_path, font_class in zip(X_train, y_train):
    copy_images_to_path(file_path, font_class, train_dir)
# Out:
# File being copied from ../experiements/data/with_mask/0-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/10-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/100-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/101-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/103-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/104-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/105-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/107-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/108-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/109-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/112-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/113-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/115-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/116-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/117-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/118-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/119-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/12-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/120-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/122-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/123-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/124-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/125-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/126-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/128-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/129-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/13-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/131-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/132-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/133-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/134-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/135-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/136-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/137-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/138-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/139-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/14-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/140-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/143-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/144-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/147-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/148-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/15-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/150-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/151-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/152-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/153-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/154-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/155-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/156-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/158-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/159-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/16-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/161-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/162-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/163-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/168-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/169-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/17-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/170-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/171-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/172-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/173-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/175-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/176-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/177-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/179-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/18-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/180-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/182-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/183-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/185-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/187-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/189-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/19-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/190-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/192-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/194-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/195-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/196-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/197-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/198-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/2-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/200-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/202-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/203-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/205-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/206-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/209-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/21-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/212-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/214-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/215-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/217-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/218-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/221-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/222-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/223-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/224-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/225-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/226-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/227-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/228-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/231-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/232-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/233-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/234-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/235-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/236-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/237-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/238-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/239-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/24-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/240-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/241-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/242-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/245-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/246-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/251-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/252-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/253-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/254-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/255-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/256-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/257-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/259-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/260-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/261-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/263-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/267-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/269-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/27-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/270-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/272-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/273-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/274-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/275-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/276-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/277-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/279-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/281-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/282-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/284-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/286-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/288-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/289-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask/29-with-mask.jpg:../experiements/dest_folder/train/with_mask
# File being copied from ../experiements/data/with_mask
jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_4.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_40.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_41.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_42.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_43.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_44.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_45.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_48.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_5.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_50.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_51.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_52.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_53.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_54.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_55.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_56.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_57.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_58.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_59.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_60.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_61.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_62.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_63.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_64.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_65.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_66.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_67.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_68.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_69.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_7.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_70.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_71.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_72.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_73.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_74.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_76.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_77.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_78.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_79.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_80.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_81.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_82.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_83.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_84.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_85.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_86.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_87.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_88.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_89.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_90.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_91.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_92.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_93.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_94.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_95.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_96.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_97.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_98.jpg:../experiements/dest_folder/train/without_mask
# File being copied from ../experiements/data/without_mask/augmented_image_99.jpg:../experiements/dest_folder/train/without_mask

# %%
for file_path, font_class in zip(X_test, y_test):
    copy_images_to_path(file_path, font_class, test_dir)
# Out:
# File being copied from ../experiements/data/with_mask/1-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/106-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/11-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/110-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/111-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/114-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/121-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/127-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/141-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/146-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/157-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/160-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/165-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/167-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/174-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/181-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/184-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/186-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/193-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/201-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/204-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/207-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/211-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/219-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/229-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/23-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/243-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/244-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/25-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/26-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/262-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/268-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/278-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/283-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/285-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/287-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/295-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/30-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/303-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/306-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/307-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/308-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/316-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/317-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/318-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/319-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/325-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/326-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/332-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/34-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/340-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/342-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/344-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/345-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/357-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/36-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/362-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/369-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/374-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/380-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/382-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/385-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/391-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/400-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/402-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/404-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/409-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/421-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/427-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/429-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/430-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/433-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/440-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/444-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/448-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/449-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/450-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/451-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/452-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/456-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/462-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/464-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/472-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/476-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/48-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/480-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/49-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/5-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/51-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/57-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/62-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/73-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/78-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/84-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/85-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/91-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/with_mask/98-with-mask.jpg:../experiements/dest_folder/test/with_mask
# File being copied from ../experiements/data/without_mask/0.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/10.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/11.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/116.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/117.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/122.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/129.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/133.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/134.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/143.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/148.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/159.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/161.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/166.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/168.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/173.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/174.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/177.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/179.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/184.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/193.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/198.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/201.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/208.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/218.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/231.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/232.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/237.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/255.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/26.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/261.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/262.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/270.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/276.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/282.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/284.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/295.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/298.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/30.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/300.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/301.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/307.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/31.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/310.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/311.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/312.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/318.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/319.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/324.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/331.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/332.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/334.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/336.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/337.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/341.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/344.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/353.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/362.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/368.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/37.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/378.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/384.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/39.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/391.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/399.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/401.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/408.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/409.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/410.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/415.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/427.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/432.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/434.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/436.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/440.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/444.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/446.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/447.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/448.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/451.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/457.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/459.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/466.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/469.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/477.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/51.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/54.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/58.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/59.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/61.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/62.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/64.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/74.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/79.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/89.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/93.jpg:../experiements/dest_folder/test/without_mask
# File being copied from ../experiements/data/without_mask/99.jpg:../experiements/dest_folder/test/without_mask

# %%
image_datasets = {x: datasets.ImageFolder(os.path.join(experiments_path, x), data_transforms[x]) for x in ['train', 'test']}

# %%
image_datasets['train']
# Out:
# Dataset ImageFolder
#     Number of datapoints: 1314
#     Root location: ../experiements/dest_folder/train
#     StandardTransform
# Transform: Compose(
#                RandomResizedCrop(size=(224, 224), scale=(0.08, 1.0), ratio=(0.75, 1.3333), interpolation=PIL.Image.BILINEAR)
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %%
image_datasets['test']
# Out:
# Dataset ImageFolder
#     Number of datapoints: 194
#     Root location: ../experiements/dest_folder/test
#     StandardTransform
# Transform: Compose(
#                Resize(size=256, interpolation=PIL.Image.BILINEAR)
#                CenterCrop(size=(224, 224))
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %%
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], 
                                             batch_size=16, 
                                             shuffle=True, 
                                             num_workers=4) 
               for x in ['train', 'test']}

# %%
dataloaders
# Out:
# {'train': <torch.utils.data.dataloader.DataLoader at 0x12aad8b50>,
#  'test': <torch.utils.data.dataloader.DataLoader at 0x12aad8ca0>}

# %%
class_names = image_datasets['train'].classes

# %%
class_names
# Out:
# ['with_mask', 'without_mask']

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cpu')

# %%
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'test']}

# %% [markdown]
# ### Visualizing images

# %%
def imshow(inp, title=None):
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.figure(figsize=(20,20))
    plt.imshow(inp)

    if title is not None:
        plt.title(title)
    plt.pause(0.001)

# %%
inputs, classes = next(iter(dataloaders['train']))
out = torchvision.utils.make_grid(inputs)

# %%
imshow(out, title=[class_names[x] for x in classes])

# %% [markdown]
# ### Training the model

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=20):
    since = time.time()
    best_acc = 0.0
    best_model = copy.deepcopy(model.state_dict())
    
    new_freeze_state = None
    prev_freeze_state = False
    for epoch in range(num_epochs):
        print("Epoch {}/{}".format(epoch, num_epochs - 1))
        print('-' * 10)
        
        for phase in ['train', 'test']:
            if phase == 'train':
                optimizer.step()
                scheduler.step()
                model.train()
            else:
                model.eval()
                
            running_loss = 0.0
            running_corrects = 0
        
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)
                
                optimizer.zero_grad()
                
                
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)
                    
                    if phase == 'train':
                        loss.backward()
                        
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            
            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            
            print('{} Loss: {:.4f} Acc:{:.4f}'.format(
                phase, epoch_loss, epoch_acc))
            
            
            if phase == 'test' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model = copy.deepcopy(model.state_dict())
            
            print()
    
    time_elapsed = time.time() - since
    print('Training complete in {:0f}m {:.0f}s'.format(
    time_elapsed // 60, time_elapsed % 60))
    print('Best val acc: {:4f}'.format(best_acc))
    
    model.load_state_dict(best_model)
    return model

# %%
import ssl

# %%
ssl._create_default_https_context = ssl._create_unverified_context

# %%
model_ft = models.resnet101(pretrained=True)

num_frts = model_ft.fc.in_features
model_ft.fc = nn.Linear(num_frts, len(class_names))

model_ft = model_ft.to(device)
criterion = nn.CrossEntropyLoss()

#optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.01, momentum=0.9)
optimizer_ft = optim.Adagrad(model_ft.parameters(), lr=0.001)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=10)
# Out:
# Epoch 0/9
# ----------
# train Loss: 0.3421 Acc:0.8516
#
# test Loss: 0.1538 Acc:0.9691
#
# Epoch 1/9
# ----------
# train Loss: 0.3340 Acc:0.8584
#
# test Loss: 0.1382 Acc:0.9742
#
# Epoch 2/9
# ----------
# train Loss: 0.3333 Acc:0.8600
#
# test Loss: 0.1615 Acc:0.9639
#
# Epoch 3/9
# ----------
# train Loss: 0.3134 Acc:0.8699
#
# test Loss: 0.1683 Acc:0.9485
#
# Epoch 4/9
# ----------
# train Loss: 0.3434 Acc:0.8554

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    #fig = plt.figure(figsize=(10,10))
    
    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['test']):
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            print(preds,"predicitons")
            
            
            for j in range(inputs.size()[0]):
                images_so_far +=1
                #ax = plt.subplot(num_images//len(labels)-1, len(labels), images_so_far)
                #ax.axis('off')
                #ax.set_title('true: {} predicted: {}'.format(class_names[labels[j]], class_names[preds[j]]))
                print('true: {} predicted: {}'.format(class_names[labels[j]], class_names[preds[j]]))
                #imshow(inputs.cpu().data[j])
                
                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
torch.save(model_ft, '../model/mask1_model_resnet101.pth')

# %%
visualize_model(model_ft)
